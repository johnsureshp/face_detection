# %% [markdown]
# <a href="https://colab.research.google.com/github/johnsureshp/face_detection/blob/main/emotionDetecton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install fer

# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches  import cv2_imshow

# %%
image = cv2.imread('/content/busiiiiii.jpg')
#/content/th.jpeg
#/content/busiiiiii.jpg
#/content/th (1).jpeg
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=595x502>

# %%
from fer import FER

# %%
detector = FER()
result = detector.detect_emotions(image)
print(result)
# Out:
# [{'box': array([223,  95, 229, 229], dtype=int32), 'emotions': {'angry': 0.07, 'disgust': 0.0, 'fear': 0.01, 'happy': 0.28, 'sad': 0.25, 'surprise': 0.0, 'neutral': 0.39}}]

# %%
emotion , score = detector.top_emotion(image)
x,y,w,h = result[0]['box']
cv2.rectangle(image ,(x,y),(x+w,y+h),(0,12,143),2)
cv2_imshow(image)
print(emotion)
# Out:
# <PIL.Image.Image image mode=RGB size=595x502>
# neutral
